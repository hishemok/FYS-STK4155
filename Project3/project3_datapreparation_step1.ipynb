# %% [markdown]
# # prepare data
#
# First we remove duplicates: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/discussion/482896

# %%
import hashlib
import os
PROJECT_DIR = "/home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive"
LABELS = ['glioma', 'meningioma', 'pituitary', 'notumor']


def compute_hash(file):
    hasher = hashlib.md5()
    with open(file, 'rb') as f:
        buf = f.read()
        hasher.update(buf)
    return hasher.hexdigest()


def list_files(hash_dict):
    for data_type in ['Training', 'Testing']:
        for label in LABELS:
            folder_path = os.path.join(PROJECT_DIR, 'raw', data_type, label)
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    if file.endswith(".jpg"):
                        file_path = os.path.join(root, file)
                        file_hash = compute_hash(file_path)
                        if file_hash in hash_dict:
                            hash_dict[file_hash].append(file_path)
                        else:
                            hash_dict[file_hash] = [file_path]


def remove_duplicates(hash_dict):
    duplicate_count = 0
    for hash_value, file_paths in hash_dict.items():
        if len(file_paths) > 1:
            for file_path in file_paths[1:]:
                print(f"Removing duplicate (hash : {hash_value}) : {file_path}")
                os.remove(file_path)
                duplicate_count += 1
    print(f"Number of duplicates : {duplicate_count}")


hash_dict = {}
list_files(hash_dict)
remove_duplicates(hash_dict)
# Out:
# Removing duplicate (hash : b0481c04cf82055b53bed325556f744e) : /home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive/raw/Testing/meningioma/Te-me_0135.jpg
# Removing duplicate (hash : ab525628d00898aa6b1088d9c1d5a785) : /home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive/raw/Training/meningioma/Tr-me_0281.jpg
# Removing duplicate (hash : af3a4cf5d54bd454b733bfe3d2177b4a) : /home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive/raw/Training/meningioma/Tr-me_0211.jpg
# Removing duplicate (hash : af3a4cf5d54bd454b733bfe3d2177b4a) : /home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive/raw/Training/meningioma/Tr-me_0366.jpg
# Removing duplicate (hash : a501e6ea3748d3aebea8e8735268ec5b) : /home/gd/Dokumente/UIOSLO/SE01/FYS_STK4155/jupyternotebooks/project3/archive/raw/Training/meningioma/Tr-me_0238.jpg
# ...
